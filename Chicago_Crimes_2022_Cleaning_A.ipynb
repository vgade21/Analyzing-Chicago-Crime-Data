# %%
import pandas as pd
import numpy as np

# %%
Crime_df = pd.read_csv('C:\\Users\\vamsh\\Documents\\Uni\\UChicago\\Autumn 2022\\MSCA 31012_IP02 - Data Engineering Platforms for Analytics\\Project\\Data\\Crimes_Circa_2022_final1.csv', encoding = 'utf-8', header = 0)

# %%
Crime_df.head(5)
# Out:
#     CRIMEID CASE NUMBER                    DATE                  BLOCK  \
# 0  12767443    JF325104  06/30/2022 08:00:00 AM       046XX N DOVER ST
# 1  12768376    JF326399  07/20/2022 12:40:00 PM        029XX W 25TH ST
# 2  12764940    JF322387  07/18/2022 05:00:00 PM        004XX E 89TH ST
# 3  12770333    JF328642  07/23/2022 01:59:00 PM  045XX N FRANCISCO AVE
# 4  12766636    JF324240  07/20/2022 04:10:00 AM    055XX S PRAIRIE AVE
#
#           PRIMARY TYPE              DESCRIPTION LOCATION DESCRIPTION  ARREST  \
# 0                THEFT            FROM BUILDING            APARTMENT   False
# 1              BATTERY  DOMESTIC BATTERY SIMPLE             SIDEWALK   False
# 2  MOTOR VEHICLE THEFT               AUTOMOBILE               STREET   False
# 3                THEFT                OVER $500               STREET   False
# 4              BATTERY  DOMESTIC BATTERY SIMPLE            APARTMENT   False
#
#    DOMESTIC  DISTRICT  COMMUNITY AREA   LATITUDE  LONGITUDE  \
# ...

# %%
# Changing format of 'DATE' to remove the AM/PM
Crime_df['DATE'] = pd.to_datetime(Crime_df['DATE'])
Crime_df['DATE']
# Out:
# 0        2022-06-30 08:00:00
# 1        2022-07-20 12:40:00
# 2        2022-07-18 17:00:00
# 3        2022-07-23 13:59:00
# 4        2022-07-20 04:10:00
#                  ...
# 192991   2022-06-09 00:00:00
# 192992   2022-06-24 15:43:00
# 192993   2022-07-01 17:29:00
# 192994   2022-07-01 19:13:00
# 192995   2022-07-01 10:45:00
# Name: DATE, Length: 192996, dtype: datetime64[ns]

# %%
Crime_df.head(5)
# Out:
#     CRIMEID CASE NUMBER                DATE                  BLOCK  \
# 0  12767443    JF325104 2022-06-30 08:00:00       046XX N DOVER ST
# 1  12768376    JF326399 2022-07-20 12:40:00        029XX W 25TH ST
# 2  12764940    JF322387 2022-07-18 17:00:00        004XX E 89TH ST
# 3  12770333    JF328642 2022-07-23 13:59:00  045XX N FRANCISCO AVE
# 4  12766636    JF324240 2022-07-20 04:10:00    055XX S PRAIRIE AVE
#
#           PRIMARY TYPE              DESCRIPTION LOCATION DESCRIPTION  ARREST  \
# 0                THEFT            FROM BUILDING            APARTMENT   False
# 1              BATTERY  DOMESTIC BATTERY SIMPLE             SIDEWALK   False
# 2  MOTOR VEHICLE THEFT               AUTOMOBILE               STREET   False
# 3                THEFT                OVER $500               STREET   False
# 4              BATTERY  DOMESTIC BATTERY SIMPLE            APARTMENT   False
#
#    DOMESTIC  DISTRICT  COMMUNITY AREA   LATITUDE  LONGITUDE  \
# ...

# %%
Crime_df.to_csv('C:\\Users\\vamsh\\Documents\\Uni\\UChicago\\Autumn 2022\\MSCA 31012_IP02 - Data Engineering Platforms for Analytics\\Project\\Data\\Crimes_Circa_2022_final2.csv', encoding='utf-8', index=False)
