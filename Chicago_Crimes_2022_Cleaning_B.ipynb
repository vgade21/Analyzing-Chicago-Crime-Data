# %%
import pandas as pd
import numpy as np

# %%
Crime_df = pd.read_csv('C:\\Users\\vamsh\\Documents\\Uni\\UChicago\\Autumn 2022\\MSCA 31012_IP02 - Data Engineering Platforms for Analytics\\Project\\Data\\Crimes_2022.csv', encoding = 'gbk', header = 0)

# %%
Crime_df.head(5)
# Out:
#          ID Case Number                    Date                  Block  IUCR  \
# 0  12767443    JF325104  06/30/2022 08:00:00 AM       046XX N DOVER ST  0890
# 1  12768376    JF326399  07/20/2022 12:40:00 PM        029XX W 25TH ST  0486
# 2  12764940    JF322387  07/18/2022 05:00:00 PM        004XX E 89TH ST  0910
# 3  12770333    JF328642  07/23/2022 01:59:00 PM  045XX N FRANCISCO AVE  0810
# 4  12766636    JF324240  07/20/2022 04:10:00 AM    055XX S PRAIRIE AVE  0486
#
#           Primary Type              Description Location Description  Arrest  \
# 0                THEFT            FROM BUILDING            APARTMENT   False
# 1              BATTERY  DOMESTIC BATTERY SIMPLE             SIDEWALK   False
# 2  MOTOR VEHICLE THEFT               AUTOMOBILE               STREET   False
# 3                THEFT                OVER $500               STREET   False
# 4              BATTERY  DOMESTIC BATTERY SIMPLE            APARTMENT   False
#
# ...

# %%
# Dropping rows with Nulls
Crime_df.dropna(axis = 0, how = 'any',inplace = True)

# %%
Crime_df.isnull().sum()
# Out:
# ID                      0
# Case Number             0
# Date                    0
# Block                   0
# IUCR                    0
# Primary Type            0
# Description             0
# Location Description    0
# Arrest                  0
# Domestic                0
# Beat                    0
# District                0
# Ward                    0
# Community Area          0
# FBI Code                0
# X Coordinate            0
# Y Coordinate            0
# Year                    0
# Updated On              0
# Latitude                0
# Longitude               0
# Location                0
# dtype: int64

# %%
# Dropping Unnecessary columns
Crime_df.drop(['IUCR', 'Beat', 'Ward', 'FBI Code', 'X Coordinate', 'Y Coordinate', 'Year', 'Updated On'], axis = 1, inplace = True)

# %%
Crime_df.shape
# Out:
# (192996, 14)

# %%
# Renaming ID column and changing all column headers to upper case for consistency
Crime_df.rename(columns={"ID":"CrimeID"}, inplace = True)
Crime_df.columns = Crime_df.columns.str.upper()
Crime_df.head(5)
# Out:
#     CRIMEID CASE NUMBER                    DATE                  BLOCK  \
# 0  12767443    JF325104  06/30/2022 08:00:00 AM       046XX N DOVER ST
# 1  12768376    JF326399  07/20/2022 12:40:00 PM        029XX W 25TH ST
# 2  12764940    JF322387  07/18/2022 05:00:00 PM        004XX E 89TH ST
# 3  12770333    JF328642  07/23/2022 01:59:00 PM  045XX N FRANCISCO AVE
# 4  12766636    JF324240  07/20/2022 04:10:00 AM    055XX S PRAIRIE AVE
#
#           PRIMARY TYPE              DESCRIPTION LOCATION DESCRIPTION  ARREST  \
# 0                THEFT            FROM BUILDING            APARTMENT   False
# 1              BATTERY  DOMESTIC BATTERY SIMPLE             SIDEWALK   False
# 2  MOTOR VEHICLE THEFT               AUTOMOBILE               STREET   False
# 3                THEFT                OVER $500               STREET   False
# 4              BATTERY  DOMESTIC BATTERY SIMPLE            APARTMENT   False
#
#    DOMESTIC  DISTRICT  COMMUNITY AREA   LATITUDE  LONGITUDE  \
# ...

# %%
Crime_df.to_csv('C:\\Users\\vamsh\\Documents\\Uni\\UChicago\\Autumn 2022\\MSCA 31012_IP02 - Data Engineering Platforms for Analytics\\Project\\Data\\Crimes_Circa_2022_final1.csv', encoding='utf-8', index=False)
