# %%
import pandas as pd
import numpy as np

# %%
Pol = pd.read_csv('C:\\Users\\vamsh\\Documents\\Uni\\UChicago\\Autumn 2022\\MSCA 31012_IP02 - Data Engineering Platforms for Analytics\\Project\\Data\\Initial\\Police_Stations.csv', encoding = 'gbk', header = 0)
Pol.head(5)
# Out:
#        DISTRICT DISTRICT NAME              ADDRESS     CITY STATE    ZIP  \
# 0  Headquarters  Headquarters  3510 S Michigan Ave  Chicago    IL  60653
# 1            18    Near North   1160 N Larrabee St  Chicago    IL  60610
# 2            19     Town Hall     850 W Addison St  Chicago    IL  60613
# 3            20       Lincoln   5400 N Lincoln Ave  Chicago    IL  60625
# 4            22   Morgan Park  1900 W Monterey Ave  Chicago    IL  60643
#
#                                              WEBSITE         PHONE  \
# 0                      http://home.chicagopolice.org           NaN
# 1  http://home.chicagopolice.org/community/distri...  312-742-5870
# 2  http://home.chicagopolice.org/community/distri...  312-744-8320
# 3  http://home.chicagopolice.org/community/distri...  312-742-8714
# 4  http://home.chicagopolice.org/community/distri...  312-745-0710
#
#             FAX           TTY  X COORDINATE  Y COORDINATE   LATITUDE  \
# ...

# %%
# Changing DISTRICT column entry for index 0 to a unique number instead of 'Headquarters' and dropping Unnecessary columns.
Pol['DISTRICT'][0] = 26
Pol.drop(['X COORDINATE', 'Y COORDINATE', 'CITY', 'STATE'], axis = 1, inplace = True)
Pol.head(5)
# Out:
# C:\Users\vamsh\AppData\Local\Temp\ipykernel_18440\800608867.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Pol['DISTRICT'][0] = 26
#   DISTRICT DISTRICT NAME              ADDRESS    ZIP  \
# 0       26  Headquarters  3510 S Michigan Ave  60653
# 1       18    Near North   1160 N Larrabee St  60610
# 2       19     Town Hall     850 W Addison St  60613
# 3       20       Lincoln   5400 N Lincoln Ave  60625
# 4       22   Morgan Park  1900 W Monterey Ave  60643
#
#                                              WEBSITE         PHONE  \
# 0                      http://home.chicagopolice.org           NaN
# 1  http://home.chicagopolice.org/community/distri...  312-742-5870
# 2  http://home.chicagopolice.org/community/distri...  312-744-8320
# ...

# %%
Pol.to_csv('C:\\Users\\vamsh\\Documents\\Uni\\UChicago\\Autumn 2022\\MSCA 31012_IP02 - Data Engineering Platforms for Analytics\\Project\\Data\\Final\\Chicago_ Police_final.csv', encoding='utf-8', index=False)
