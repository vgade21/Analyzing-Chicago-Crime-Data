# %%
import pandas as pd
import numpy as np

# %%
Afford = pd.read_csv('C:\\Users\\vamsh\\Documents\\Uni\\UChicago\\Autumn 2022\\MSCA 31012_IP02 - Data Engineering Platforms for Analytics\\Project\\Data\\Affordable_Rental_Housing_Developments.csv', encoding = 'gbk', header = 0)
Afford.head(5)
# Out:
#   COMMUNITY AREA NAME  COMMUNITY AREA NUMBER               PROPERTY TYPE  \
# 0  East Garfield Park                     27         Multifamily/Artists
# 1      North Lawndale                     29                 Multifamily
# 2       Humboldt Park                     23  Supportive/Males 18-24yrs.
# 3     Grand Boulevard                     38                 Multifamily
# 4     Washington Park                     40    People with Disabilities
#
#                                     PROPERTY NAME                  ADDRESS  \
# 0                         Switching Station Lofts         15 S. Homan Ave.
# 1                          Dicksons Estates Apts.  1129 S. Sacramento Ave.
# 2         Solid Ground Supportive Housing Program       3507 W. North Ave.
# 3  Hearts United I-The Langston (scattered sites)     722-46 E. Bowen Ave.
# 4                             Urbanite Apartments    5441 S. Michigan Ave.
#
# ...

# %%
# Dropping Unnecessary columns and changing column headers to upper case for consistency
Afford.columns = Afford.columns.str.upper()
Afford.drop(['X COORDINATE', 'Y COORDINATE'], axis = 1, inplace = True)
Afford.head(5)
# Out:
#   COMMUNITY AREA NAME  COMMUNITY AREA NUMBER               PROPERTY TYPE  \
# 0  East Garfield Park                     27         Multifamily/Artists
# 1      North Lawndale                     29                 Multifamily
# 2       Humboldt Park                     23  Supportive/Males 18-24yrs.
# 3     Grand Boulevard                     38                 Multifamily
# 4     Washington Park                     40    People with Disabilities
# 5      North Lawndale                     29                 Multifamily
# 6            New City                     61                      Senior
# 7        Logan Square                     22                         ARO
# 8           West Town                     24                 Multifamily
# 9              Uptown                      3                         ARO
#
#                                     PROPERTY NAME                  ADDRESS  \
# 0                         Switching Station Lofts         15 S. Homan Ave.
# ...

# %%
Afford.to_csv('C:\\Users\\vamsh\\Documents\\Uni\\UChicago\\Autumn 2022\\MSCA 31012_IP02 - Data Engineering Platforms for Analytics\\Project\\Data\\Final\\Affordable_Rental_Housing_Developments_final3.csv', encoding='utf-8', index=False)
